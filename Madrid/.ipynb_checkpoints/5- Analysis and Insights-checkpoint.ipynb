# %% [markdown]
# # ANALYSIS AND INSIGHTS

# %% [markdown]
# ## SET UP

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import sqlalchemy as sa


# %config IPCompleter.greedy=True

pd.options.display.max_columns = None

# %% [markdown]
# ## DATA LOAD

# %%
con = sa.create_engine('sqlite:///data/airbnb.db')

df = pd.read_sql('df_preparado', con = con)

df.head()
# Out:
#    level_0  index     id                                      name    host_id  \
# 0        0      0   6369  Rooftop terrace room ,  ensuite bathroom      13660
# 1        1      1  21853                      Bright and airy room      83531
# 2        2      2  23001         Apartmento Arganzuela- Madrid Rio      82175
# 3        3      3  24805                    Gran Via Studio Madrid  346366726
# 4        4      4  26825        Single Room whith private Bathroom     114340
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0           Chamartín  Hispanoamérica  40.45724   -3.67688     Private room
# 1              Latina        Cármenes  40.40381   -3.74130     Private room
# 2          Arganzuela         Legazpi  40.38840   -3.69511  Entire home/apt
# 3              Centro     Universidad  40.42183   -3.70529  Entire home/apt
# 4          Arganzuela         Legazpi  40.38975   -3.69018     Private room
#
#    price  minimum_nights  calculated_host_listings_count  availability_365  \
# 0     60               1                               2               180
# 1     31               4                               2               364
# 2     50              15                               5               222
# 3     92               5                               1               115
# 4     26               2                               1               349
#
#                                          description host_is_superhost  \
# 0  Excellent connection with the AIRPORT and EXHI...                 t
# 1  We have a quiet and sunny room with a good vie...                 f
# 2  Apartamento de tres dormitorios dobles, gran s...                 f
# 3  Studio located 50 meters from Gran Via, next t...                 f
# 4  Nice and cozy roon for one person with a priva...                 f
#
#    accommodates  bedrooms  beds  number_of_reviews  review_scores_rating  \
# 0             2       1.0   1.0                 80                  4.87
# 1             1       1.0   1.0                 33                  4.58
# 2             6       3.0   5.0                  0                   NaN
# 3             3       1.0   1.0                 12                  4.92
# 4             1       1.0   1.0                149                  4.68
#
#    review_scores_communication  review_scores_location  precio_m2    distrito  \
# 0                         4.89                    4.77       5098   Chamartín
# 1                         4.82                    4.21       2267      Latina
# 2                          NaN                     NaN       4085  Arganzuela
# 3                         5.00                    5.00       4827      Centro
# 4                         4.71                    4.70       4085  Arganzuela
#
#    precio_total  ocupacion bedrooms_disc accommodates_disc beds_disc  \
# 0          60.0         50        01_Una               0-3         1
# 1          31.0          0        01_Una               0-3         1
# 2          50.0         39       03_Tres              5-16      3-24
# 3          92.0         68        01_Una               0-3         1
# 4          26.0          4        01_Una               0-3         1
#
#   number_of_reviews_disc  m2  precio_compra   pdi_sol
# 0                 48-744  50       178430.0  5.032039
# 1                   5-48  50        79345.0  3.521406
# 2                    1-4  90       257355.0  3.226963
# 3                   5-48  50       168945.0  0.591065
# 4                 48-744  50       142975.0  3.200942

# %% [markdown]
# ## ANALYSIS

# %% [markdown]
# ### Analysis on pricing

# %% [markdown]
# **What is the average price? And the price range? And by district? And by neighborhood?**
#
# **What is the ranking of districts and neighborhoods by average rental price?**

# %%
df.precio_total.describe()
# Out:
# count    17710.000000
# mean       149.027770
# std        523.211567
# min         20.000000
# 25%         43.000000
# 50%         70.000000
# 75%        112.000000
# max      22400.000000
# Name: precio_total, dtype: float64

# %% [markdown]
# We see that there is at least one outlier at the top that skews the mean, so we will use the median as a more reliable measure of centralization.

# %%
df.precio_total.median()
# Out:
# 70.0

# %%
df.groupby('distrito').precio_total.median().sort_values(ascending = False)
# Out:
# distrito
# San Blas - Canillejas    90.0
# Salamanca                88.0
# Centro                   76.0
# Chamartín                74.0
# Chamberí                 70.0
# Hortaleza                69.0
# Retiro                   68.0
# Tetuán                   66.0
# Moncloa - Aravaca        61.0
# Fuencarral - El Pardo    60.0
# Arganzuela               58.0
# Vicálvaro                53.0
# Ciudad Lineal            50.0
# Barajas                  49.5
# Carabanchel              48.0
# Villa de Vallecas        47.5
# Latina                   47.0
# Usera                    42.0
# Villaverde               42.0
# Moratalaz                40.0
# Puente de Vallecas       40.0
# Name: precio_total, dtype: float64

# %% [markdown]
# The San Blas data is very weird, let's see what's hapenning.

# %%
df.loc[df.distrito == 'San Blas - Canillejas'].sort_values('precio_total',ascending = False).head(10)
# Out:
#        level_0  index        id  \
# 9290      9290   9290  34600594
# 9662      9662   9662  34826962
# 10189    10189  10189  35149419
# 9668      9668   9668  34833756
# 9878      9878   9878  34970236
# 9748      9748   9748  34882596
# 9173      9173   9173  34522997
# 9831      9831   9831  34933116
# 10092    10092  10092  35091283
# 10404    10404  10404  35251141
#
#                                                     name    host_id  \
# 9290                                  3 rooms near Wanda   38951538
# 9662                                         Pozos rooms  222068421
# 10189       CHALET FOR THE FINAL CHAMPIONS LEAGUE MADRID  143732655
# 9668                               Wanda Champions Final   29628177
# 9878   Habitaciones cerca Wanda Metropolitano (Champi...  263474389
# 9748                                  2 rooms near wanda   38951538
# 9173     Beautiful Penthouse next to Wanda Metropolitano  260551569
# 9831                       FINAL CHAMPIONS LEAGUE MADRID  263232278
# 10092                             FINAL CHAMPIONS LEAGUE  264225539
# 10404        Se alquila para final de la champion league  265376740
#
#          neighbourhood_group neighbourhood  latitude  longitude  \
# 9290   San Blas - Canillejas         Arcos  40.42105   -3.61457
# 9662   San Blas - Canillejas         Arcos  40.41927   -3.61555
# 10189  San Blas - Canillejas    Canillejas  40.44937   -3.61633
# 9668   San Blas - Canillejas         Rosas  40.42622   -3.60502
# 9878   San Blas - Canillejas         Arcos  40.41920   -3.61229
# 9748   San Blas - Canillejas         Arcos  40.41948   -3.61427
# 9173   San Blas - Canillejas    Canillejas  40.43686   -3.61093
# 9831   San Blas - Canillejas      Simancas  40.43968   -3.61933
# 10092  San Blas - Canillejas         Rejas  40.44592   -3.58746
# 10404  San Blas - Canillejas    Canillejas  40.44292   -3.60764
#
#              room_type  price  minimum_nights  calculated_host_listings_count  \
# 9290      Private room   2800               1                               2
# 9662      Private room   3000               1                               1
# 10189  Entire home/apt   6000               1                               1
# 9668      Private room   2700               1                               1
# 9878      Private room    800               1                               1
# 9748      Private room   1500               1                               2
# 9173      Private room   2000               1                               1
# 9831      Private room   2000               2                               1
# 10092     Private room   1000               1                               1
# 10404  Entire home/apt   3000               1                               1
#
#        availability_365                                        description  \
# 9290                  0                     3 rooms 15´walking from Wanda.
# 9662                 88  Cerca nos podemos encontrar un centro comercia...
# 10189               365  We are talking about one of the last villas fo...
# 9668                  0  Somos una pareja joven educados y muy sociable...
# 9878                 88  Se alquilan 5 habitaciones, cada una para 2 hu...
# 9748                363  2 rooms near Wanda stadium (20' walking) with ...
# 9173                  0  Wonderful penthouse in a lovely duplex next to...
# 9831                365  Near (15 minutes walking) to WANDA STADIUM.<br...
# 10092               180  Desayuno, comida y cena incluida. Traslados al...
# 10404               365                                               None
#
#       host_is_superhost  accommodates  bedrooms  beds  number_of_reviews  \
# 9290                  f             6       3.0   5.0                  0
# 9662                  f             4       2.0   3.0                  0
# 10189                 f             6       4.0   5.0                  0
# 9668                  f             5       2.0   3.0                  0
# 9878                  f            10       5.0   8.0                  0
# 9748                  f             4       2.0   4.0                  0
# 9173                  f             4       1.0   3.0                  0
# 9831                  f             5       3.0   3.0                  0
# 10092                 f             6       2.0   6.0                  0
# 10404                 f             1       2.0   4.0                  0
#
#        review_scores_rating  review_scores_communication  \
# 9290                    NaN                          NaN
# 9662                    NaN                          NaN
# 10189                   NaN                          NaN
# 9668                    NaN                          NaN
# 9878                    NaN                          NaN
# 9748                    NaN                          NaN
# 9173                    NaN                          NaN
# 9831                    NaN                          NaN
# 10092                   NaN                          NaN
# 10404                   NaN                          NaN
#
#        review_scores_location  precio_m2               distrito  precio_total  \
# 9290                      NaN       2591  San Blas - Canillejas        9800.0
# 9662                      NaN       2591  San Blas - Canillejas        6300.0
# 10189                     NaN       2591  San Blas - Canillejas        6000.0
# 9668                      NaN       2591  San Blas - Canillejas        5670.0
# 9878                      NaN       2591  San Blas - Canillejas        4480.0
# 9748                      NaN       2591  San Blas - Canillejas        4200.0
# 9173                      NaN       2591  San Blas - Canillejas        4200.0
# 9831                      NaN       2591  San Blas - Canillejas        4200.0
# 10092                     NaN       2591  San Blas - Canillejas        4200.0
# 10404                     NaN       2591  San Blas - Canillejas        3000.0
#
#        ocupacion    bedrooms_disc accommodates_disc beds_disc  \
# 9290         100          03_Tres              5-16      3-24
# 9662          75           02_Dos                 4         2
# 10189          0  04_Cuatro o mas              5-16      3-24
# 9668         100           02_Dos              5-16         2
# 9878          75  04_Cuatro o mas              5-16      3-24
# 9748           0           02_Dos                 4      3-24
# 9173         100           01_Una                 4         2
# 9831           0          03_Tres              5-16         2
# 10092         50           02_Dos              5-16      3-24
# 10404          0           02_Dos               0-3      3-24
#
#       number_of_reviews_disc   m2  precio_compra    pdi_sol
# 9290                     1-4   90       163233.0   7.532233
# 9662                     1-4   70       126959.0   7.439364
# 10189                    1-4  120       217644.0   8.212429
# 9668                     1-4   70       126959.0   8.391922
# 9878                     1-4  150       272055.0   7.714952
# 9748                     1-4   70       126959.0   7.548577
# 9173                     1-4   50        90685.0   8.138310
# 9831                     1-4   90       163233.0   7.557076
# 10092                    1-4   70       126959.0  10.334061
# 10404                    1-4   70       126959.0   8.610212

# %% [markdown]
# The prices are around 3,000 - 5,000 euros
#
# The descriptions mention the Champions League final...
#
# **Insight 1: there may be properties with a regular residual value but with high value at specific times due to sporting events or shows**
#
# Would it make sense to create a rental product that consists of renting in a "normal" way at a price below the market with the condition that the tenant vacates the apartment to rent it "for tourism" on certain dates?

# %% [markdown]
# The rest is as expected, with districts like Salamanca, Centro or Chanmartín ahead.
#
# But for example median price difference between Retiro and Tetuán is very low, which implies we could compare the median price by district with the median purchase price also by district.

# %%
temp = df.groupby('distrito')[['precio_total','precio_compra']].median()
temp
# Out:
#                        precio_total  precio_compra
# distrito
# Arganzuela                     58.0       142975.0
# Barajas                        49.5       119315.0
# Carabanchel                    48.0        74305.0
# Centro                         76.0       168945.0
# Chamartín                      74.0       178430.0
# Chamberí                       70.0       188335.0
# Ciudad Lineal                  50.0       102900.0
# Fuencarral - El Pardo          60.0       124880.0
# Hortaleza                      69.0       135485.0
# Latina                         47.0        79345.0
# Moncloa - Aravaca              61.0       141155.0
# Moratalaz                      40.0        87500.0
# Puente de Vallecas             40.0        67130.0
# Retiro                         68.0       167580.0
# Salamanca                      88.0       213990.0
# San Blas - Canillejas          90.0        90685.0
# Tetuán                         66.0       128730.0
# Usera                          42.0        69825.0
# Vicálvaro                      53.0        84105.0
# Villa de Vallecas              47.5        82390.0
# Villaverde                     42.0        59255.0

# %%
plt.figure(figsize = (16,8))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# There is a clear correlation between the purchase price in each district and the price we can charge.
#
# There are clearly three clusters: low-low, medium-medium and high-high.
#
# And the exception here is San Blas, which we already know why.
#
# Therefore, as expected, there is no clear "bargain" at this level.
#
# Let's repeat the analysis at the neighborhood level.

# %%
temp = df.groupby('neighbourhood')[['precio_total','precio_compra']].median()
temp
# Out:
#                precio_total  precio_compra
# neighbourhood
# Abrantes               35.5        74305.0
# Acacias                53.8       142975.0
# Adelfas                54.0       234612.0
# Aeropuerto             41.3       119315.0
# Aguilas                47.0        79345.0
# ...                     ...            ...
# Valverde               62.5       124880.0
# Ventas                 42.0       102900.0
# Vinateros              50.0        87500.0
# Vista Alegre           50.0        74305.0
# Zofío                  36.4        69825.0
#
# [128 rows x 2 columns]

# %%
plt.figure(figsize = (16,20))
sns.scatterplot(data = temp, x = 'precio_compra', y = 'precio_total')
#Ponemos las etiquetas
for cada in range(0,temp.shape[0]):
    plt.text(temp.precio_compra.iloc[cada], temp.precio_total.iloc[cada], temp.index[cada])

# %% [markdown]
# At this level we can see more things:
#
# * 3 neighborhoods that stand out, possibly all 3 are from San Blas
# * Within each low-medium-high group we can start to separate
# * Low: Simancas, Ambroz, Marroquina, San Juan Bautista
# * Medium: El Plantio, Valdemarín, Valdefuentes
# * Medium-high: Jerónimos, Fuentela reina
# * High: Recoletos
#
# **Insight 2: There are certain neighborhoods that at first glance can maximize the cost-income ratio and we can also segment it by the type of quality of the property in which we are interested in investing**

# %%
df.loc[df.neighbourhood.isin(['Rosas','Canillejas','Hellin']),'distrito'].unique()
# Out:
# array(['San Blas - Canillejas'], dtype=object)

# %% [markdown]
# **What factors (apart from location) determine the rental price?**

# %% [markdown]
# we can build a minicube, since we have discretized our analysis variables.

# %%
#Step 1: Select which variables will be the metrics and which will be the dimensions
metricas = ['precio_total','precio_compra']
dimensiones = ['bedrooms_disc','accommodates_disc','beds_disc','number_of_reviews_disc']

minicubo_precio = df[dimensiones + metricas]
minicubo_precio
# Out:
#       bedrooms_disc accommodates_disc beds_disc number_of_reviews_disc  \
# 0            01_Una               0-3         1                 48-744
# 1            01_Una               0-3         1                   5-48
# 2           03_Tres              5-16      3-24                    1-4
# 3            01_Una               0-3         1                   5-48
# 4            01_Una               0-3         1                 48-744
# ...             ...               ...       ...                    ...
# 17705        01_Una               0-3         1                    1-4
# 17706        01_Una               0-3         1                    1-4
# 17707        01_Una               0-3         1                    1-4
# 17708        01_Una               0-3         1                    1-4
# 17709        01_Una               0-3         1                    1-4
#
#        precio_total  precio_compra
# 0              60.0       178430.0
# 1              31.0        79345.0
# 2              50.0       257355.0
# 3              92.0       168945.0
# 4              26.0       142975.0
# ...             ...            ...
# 17705          29.0       168945.0
# 17706          29.0       168945.0
# 17707          29.0       168945.0
# 17708          29.0       213990.0
# 17709          33.0       168945.0
#
# [17710 rows x 6 columns]

# %%
#Step 2: convert dimensions to transactional
minicubo_precio = minicubo_precio.melt(id_vars=['precio_total','precio_compra'])
minicubo_precio
# Out:
#        precio_total  precio_compra                variable    value
# 0              60.0       178430.0           bedrooms_disc   01_Una
# 1              31.0        79345.0           bedrooms_disc   01_Una
# 2              50.0       257355.0           bedrooms_disc  03_Tres
# 3              92.0       168945.0           bedrooms_disc   01_Una
# 4              26.0       142975.0           bedrooms_disc   01_Una
# ...             ...            ...                     ...      ...
# 70835          29.0       168945.0  number_of_reviews_disc      1-4
# 70836          29.0       168945.0  number_of_reviews_disc      1-4
# 70837          29.0       168945.0  number_of_reviews_disc      1-4
# 70838          29.0       213990.0  number_of_reviews_disc      1-4
# 70839          33.0       168945.0  number_of_reviews_disc      1-4
#
# [70840 rows x 4 columns]

# %%
#Step 3: Add the metrics by "variable" and "value" with the desired functions

minicubo_precio = minicubo_precio.groupby(['variable','value'])[['precio_total','precio_compra']].agg('median')
minicubo_precio
# Out:
#                                         precio_total  precio_compra
# variable               value
# accommodates_disc      0-3                      50.0       168945.0
#                        4                        86.0       168945.0
#                        5-16                    126.0       236523.0
# bedrooms_disc          01_Una                   56.0       168945.0
#                        02_Dos                  100.0       236523.0
#                        03_Tres                 140.0       304101.0
#                        04_Cuatro o mas         204.0       405468.0
# beds_disc              1                        59.0       168945.0
#                        2                       100.0       236523.0
#                        3-24                    139.0       257355.0
# number_of_reviews_disc 1-4                      70.0       168945.0
#                        48-744                   68.0       168945.0
#                        5-48                     69.0       168945.0

# %% [markdown]
# Now on the minicube, we analyze each variable

# %%
minicubo_precio.loc['bedrooms_disc']
# Out:
#                  precio_total  precio_compra
# value
# 01_Una                   56.0       168945.0
# 02_Dos                  100.0       236523.0
# 03_Tres                 140.0       304101.0
# 04_Cuatro o mas         204.0       405468.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['bedrooms_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['bedrooms_disc'].precio_compra,color = 'green');

# %% [markdown]
# Nothing to highlight for the number of rooms.
#
# There is an almost perfect relationship between the purchase price and the total price that can be charged.
#
# Part of this effect may be artificial, since we use the number of rooms to calculate the total price as the purchase price.

# %%
minicubo_precio.loc['beds_disc']
# Out:
#        precio_total  precio_compra
# value
# 1              59.0       168945.0
# 2             100.0       236523.0
# 3-24          139.0       257355.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['beds_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['beds_disc'].precio_compra,color = 'green');

# %% [markdown]
# About the number of beds, there is one conclusion:
#
# **Insight 3: the number of beds to avoid is 2**. Either we put one bed or we try to fit as many as possible.
#
# Since there was no effect on the number of rooms, could it be that the owners are trying to fit many more beds than rooms to maximize income?
#
# Let's look at this for example with one-bedroom apartments:

# %%
df[df.bedrooms == 1].groupby('beds').precio_total.median().plot();

# %% [markdown]
# There's definetly something here, the graph shows that there is even people trying to squeeze tens of beds in a single room.

# %%
df.loc[(df.bedrooms == 1)& (df.beds > 8)]
# Out:
#        level_0  index        id  \
# 357        357    357   1044902
# 605        605    605   2143824
# 710        710    710   3011110
# 11848    11848  11848  39600798
# 13340    13340  13340  42492960
# 15722    15722  15722  48855617
#
#                                                     name    host_id  \
# 357                                    Masía el Ferrajón    5751753
# 605                    The Hat Madrid - 10 people shared   10940437
# 710                  The Hat Madrid-Compartida 10 pers 2   10940437
# 11848  Bed in a 10-Bed Dormitory In the Centre of Madrid  304035848
# 13340              Apartamento dúplex 10camas en literas  338384437
# 15722   habitaciones en una casa tranquila, en el centro  194738186
#
#       neighbourhood_group         neighbourhood  latitude  longitude  \
# 357     Moncloa - Aravaca  Ciudad Universitaria  40.46549   -3.75115
# 605                Centro                   Sol  40.41511   -3.70804
# 710                Centro           Embajadores  40.41311   -3.70621
# 11848              Centro              Justicia  40.42710   -3.69912
# 13340              Tetuán        Cuatro Caminos  40.44959   -3.70138
# 15722           Salamanca      Fuente del Berro  40.42604   -3.66373
#
#           room_type  price  minimum_nights  calculated_host_listings_count  \
# 357    Private room    112               2                               1
# 605     Shared room     24               1                               6
# 710     Shared room     24               1                               6
# 11848   Shared room     20               1                              13
# 13340  Private room    298               1                               1
# 15722  Private room     36               2                               1
#
#        availability_365                                        description  \
# 357                   0  <b>The space</b><br />Masía el Ferrajón featur...
# 605                 364  10 people shared room with shared bathroom. <b...
# 710                 364  The Hat Madrid es el primer Boutique Hostel de...
# 11848               351  Low-key, hostel-style setup on a tree-lined st...
# 13340               364  Vivienda en planta baja con 10 plazas distribu...
# 15722               359  Es una casa que tiene dos habitaciones que se ...
#
#       host_is_superhost  accommodates  bedrooms  beds  number_of_reviews  \
# 357                   f            16       1.0  14.0                  0
# 605                   t            10       1.0  10.0                 91
# 710                   t            10       1.0  10.0                 28
# 11848                 f             1       1.0  10.0                  2
# 13340                 f            10       1.0  10.0                  1
# 15722                 f             5       1.0   9.0                  0
#
#        review_scores_rating  review_scores_communication  \
# 357                     NaN                          NaN
# 605                    4.57                         4.69
# 710                    4.56                         4.81
# 11848                  5.00                         5.00
# 13340                  5.00                         4.00
# 15722                   NaN                          NaN
#
#        review_scores_location  precio_m2           distrito  precio_total  \
# 357                       NaN       4033  Moncloa - Aravaca        1097.6
# 605                      4.84       4827             Centro         168.0
# 710                      4.93       4827             Centro         168.0
# 11848                    5.00       4827             Centro         140.0
# 13340                    5.00       3678             Tetuán        2086.0
# 15722                     NaN       6114          Salamanca         226.8
#
#        ocupacion bedrooms_disc accommodates_disc beds_disc  \
# 357          100        01_Una              5-16      3-24
# 605            0        01_Una              5-16      3-24
# 710            0        01_Una              5-16      3-24
# 11848          3        01_Una               0-3      3-24
# 13340          0        01_Una              5-16      3-24
# 15722          1        01_Una              5-16      3-24
#
#       number_of_reviews_disc  m2  precio_compra   pdi_sol
# 357                      1-4  50       141155.0  6.767308
# 605                   48-744  50       168945.0  0.436897
# 710                     5-48  50       168945.0  0.470155
# 11848                    1-4  50       168945.0  1.207701
# 13340                    1-4  50       128730.0  3.658902
# 15722                    1-4  50       213990.0  3.510206

# %% [markdown]
# Let's now look at the number of guests they accept.

# %%
minicubo_precio.loc['accommodates_disc']
# Out:
#        precio_total  precio_compra
# value
# 0-3            50.0       168945.0
# 4              86.0       168945.0
# 5-16          126.0       236523.0

# %%
f, ax = plt.subplots()
ax.plot(minicubo_precio.loc['accommodates_disc'].precio_total)
ax2 = ax.twinx()
ax2.plot(minicubo_precio.loc['accommodates_disc'].precio_compra,color = 'green');

# %% [markdown]
# **Insight 4: The optimal number of guests is 3, since the price of the properties to accommodate 3 is the same as to accommodate 1 or 2. From 4 onwards the apartment needs to be larger and the purchase price increases considerably**

# %% [markdown]
# Finally, we are going to analyse the variable we have constructed for proximity to a point of interest to see if it has an effect on the price of the rooms.
#
# In a real situation we would have constructed many of this type, and repeated the analysis with all of them.
#
# In this case, since we have constructed the distance to Puerta del Sol, we are going to evaluate only the districts for which this may be relevant, that is, the most central ones.
#
# To do this, we are first going to calculate the average distance per district and choose a cut-off point.

# %%
df.groupby('distrito').pdi_sol.median().sort_values()
# Out:
# distrito
# Centro                    0.728581
# Arganzuela                1.817840
# Chamberí                  2.078790
# Moncloa - Aravaca         2.130135
# Retiro                    2.415432
# Salamanca                 2.705209
# Latina                    3.496952
# Carabanchel               3.647956
# Usera                     3.661376
# Chamartín                 4.233216
# Puente de Vallecas        4.233631
# Tetuán                    4.572866
# Ciudad Lineal             5.170226
# Moratalaz                 5.242395
# Villaverde                7.579665
# Fuencarral - El Pardo     7.738933
# San Blas - Canillejas     7.962141
# Hortaleza                 8.132864
# Vicálvaro                 8.396723
# Villa de Vallecas         8.822907
# Barajas                  11.593340
# Name: pdi_sol, dtype: float64

# %%
df.groupby('distrito').pdi_sol.median().sort_values()[0:7].index.to_list()
# Out:
# ['Centro',
#  'Arganzuela',
#  'Chamberí',
#  'Moncloa - Aravaca',
#  'Retiro',
#  'Salamanca',
#  'Latina']

# %%
seleccion = df.groupby('distrito').pdi_sol.median().sort_values()[0:7].index.to_list()

plt.figure(figsize = (16,12))
sns.scatterplot(data = df.loc[df.distrito.isin(seleccion)], x = 'pdi_sol', y = 'precio_total');

# %% [markdown]
# There doesn't seem to be as direct a relationship as one might expect between the distance to Puerta del Sol and the rental price.

# %% [markdown]
# **Insight 5: Being within the district, it seems that proximity to points of interest does not have as much impact as would be expected. This opens the door to looking for properties that, while in a central district, are not right next to the POI and therefore, hopefully, have a lower purchase price**

# %% [markdown]
# ### Geographic analysis on a map

# %% [markdown]
# Ok now let's have some fun. Geographic analysis is very deep itself, but we're going to use a simple Python alternative to play with

# %%
import folium

# %%
folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83c2774ad8a72552deab7670a36b1860 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83c2774ad8a72552deab7670a36b1860&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83c2774ad8a72552deab7670a36b1860 = L.map(
#                 &quot;map_83c2774ad8a72552deab7670a36b1860&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3cb2a6ae0caf34f9f7e8bf9d6fe8e5ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3cb2a6ae0caf34f9f7e8bf9d6fe8e5ca.addTo(map_83c2774ad8a72552deab7670a36b1860);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Let's see the San Blas district.

# %%
datos = df[df.distrito == 'San Blas - Canillejas'].copy()

# %%
mapa = folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)

for piso in range(0,len(datos)):
   folium.Marker(
      location = [datos.iloc[piso]['latitude'], datos.iloc[piso]['longitude']],
      popup = datos.iloc[piso]['precio_total'],
   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48dd555db7757c1d5d8c6187e9e7f4f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48dd555db7757c1d5d8c6187e9e7f4f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48dd555db7757c1d5d8c6187e9e7f4f6 = L.map(
#                 &quot;map_48dd555db7757c1d5d8c6187e9e7f4f6&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f12ce307cd482d197ce4198dc384c6e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_f12ce307cd482d197ce4198dc384c6e1.addTo(map_48dd555db7757c1d5d8c6187e9e7f4f6);
#
#
#             var marker_2905e7e0ee5d5f4492004ceac4e59690 = L.marker(
#                 [40.43202, -3.60353],
#                 {}
#             ).addTo(map_48dd555db7757c1d5d8c6187e9e7f4f6);
#
#
#         var popup_b5054082625c1ff1ac1bb8b2a1feb1a9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d28f29470d2b90bed0eb88d5badbeffb = $(`&lt;div id=&quot;html_d28f29470d2b90bed0eb88d5badbeffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36.0&lt;/div&gt;`)[0];
#                 popup_b5054082625c1ff1ac1bb8b2a1feb1a9.setContent(html_d28f29470d2b90bed0eb88d5badbeffb);
#
#
#
#         marker_2905e7e0ee5d5f4492004ceac4e59690.bindPopup(popup_b5054082625c1ff1ac1bb8b2a1feb1a9)
#         ;
#
#
#
#
#             var marker_586650fe9b2167f749d5f5dee0bf6c8b = L.marker(
#                 [40.42756, -3.61577],
#                 {}
#             ).addTo(map_48dd555db7757c1d5d8c6187e9e7f4f6);
#
#
#         var popup_109d8731a4573510527bee5ec4e64677 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf2c8cb7b4240e56541484dfb649db30 = $(`&lt;div id=&quot;html_cf2c8cb7b4240e56541484dfb649db30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_109d8731a4573510527bee5ec4e64677.setContent(html_cf2c8cb7b4240e56541484dfb649db30);
#
#
#
#         marker_586650fe9b2167f749d5f5dee0bf6c8b.bindPopup(popup_109d8731a4573510527bee5ec4e64677)
#         ;
#
#
#
#
#             var marker_e9721b74eec2bdb6e2de4942d9ebe87e = L.marker(
#                 [40.42761, -3.6158],
#                 {}
#             ).addTo(map_48dd555db7757c1d5d8c6187e9e7f4f6);
#
#
#         var popup_e679e375ac346cf1c62fe3c8bd0b16ab = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d084bf1442fe8bc5d8699b1c8d06ed29 = $(`&lt;div id=&quot;html_d084bf1442fe8bc5d8699b1c8d06ed29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_e679e375ac346cf1c62fe3c8bd0b16ab.setContent(html_d084bf1442fe8bc5d8699b1c8d06ed29);
#
#
#
#         marker_e9721b74eec2bdb6e2de4942d9ebe87e.bindPopup(popup_e679e375ac346cf1c62fe3c8bd0b16ab)
#         ;
#
#
#
#
#             var marker_946674ed8d9ae38a7505e218de3828ea = L.marker(
#                 [40.4267, -3.61631],
#                 {}
#             ).addTo(map_48dd555db7757c1d5d8c6187e9e7f4f6);
#
#
#         var popup_adad301843e4abd091e009dee6b1570f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56fe6731fb5027485386979e1e461120 = $(`&lt;div id=&quot;html_56fe6731fb5027485386979e1e461120&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;21.0&lt;/div&gt;`)[0];
#                 popup_adad301843e4abd091e009dee6b1570f.setContent(html_56fe6731fb5027485386979e1e461120);
#
#
#
#         marker_946674ed8d9ae38a7505e218de3828ea.bindPopup(popup_adad301843e4abd091e009dee6b1570f)
#         ;
#
#
#
#
#             var marker_2b98a3b53609b2b7ddf299bfb3ea2295 = L.marker(
#                 [40.44791, -3.57918],
#                 {}
#             ).addTo(map_48dd555db7757c1d5d8c6187e9e7f4f6);
#
#
#         var popup_da2a2d6e5e7a84d2a3f683b6c5e1d199 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2a0d46abb50954d4e55bb17872237937 = $(`&lt;div id=&quot;html_2a0d46abb50954d4e55bb17872237937&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;85.0&lt;/div&gt;`)[0];
#                 popup_da2a2d6e5e7a84d2a3f683b6c5e1d199.setContent(html_2a0d46abb50954d4e55bb17872237937);
#
#
#
#         marker_2b98a3b53609b2b7ddf299bfb3ea2295.bindPopup(popup_da2a2d6e5e7a84d2a3f683b6c5e1d199)
#         ;
#
#
#
#
#             var marker_df920d434eb6ed740a79583f7e4b0a3f = L.marker(
#                 [40.44655, -3.58128],
#                 {}
#             ).addTo(map_48dd555db7757c1d5d8c6187e9e7f4f6);
#
#
#         var popup_d9ede73dce7f4ce7b07898ac

# %% [markdown]
# Let's try to make it more visual

# %%
datos['precio_total_disc'] = pd.qcut(datos['precio_total'], q = [0, .25, .5, .75, 1.], 
                              labels=['yellow', 'orange', 'blue', 'red'])

# %%
mapa = folium.Map(location=[40.4167278, -3.7033387],zoom_start=12)

for piso in range(0,len(datos)):
   folium.CircleMarker(
      location = [datos.iloc[piso]['latitude'], datos.iloc[piso]['longitude']],
      popup = datos.iloc[piso]['precio_total'],
      fill=True,
      color = datos.iloc[piso]['precio_total_disc'],
      fill_opacity=1,
      radius = 5
   ).add_to(mapa)

mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66422fdbc76bdc969dc5909ed82fc69a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66422fdbc76bdc969dc5909ed82fc69a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66422fdbc76bdc969dc5909ed82fc69a = L.map(
#                 &quot;map_66422fdbc76bdc969dc5909ed82fc69a&quot;,
#                 {
#                     center: [40.4167278, -3.7033387],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b178143f8b3d9a9fac62ab61d59484a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_b178143f8b3d9a9fac62ab61d59484a6.addTo(map_66422fdbc76bdc969dc5909ed82fc69a);
#
#
#             var circle_marker_c255077ca9e8b873ca58e3538d0d3322 = L.circleMarker(
#                 [40.43202, -3.60353],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_66422fdbc76bdc969dc5909ed82fc69a);
#
#
#         var popup_8ecc4558894f64915f311b821ade830d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f80bb9e515bd37d39a5c4111e4d98321 = $(`&lt;div id=&quot;html_f80bb9e515bd37d39a5c4111e4d98321&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;36.0&lt;/div&gt;`)[0];
#                 popup_8ecc4558894f64915f311b821ade830d.setContent(html_f80bb9e515bd37d39a5c4111e4d98321);
#
#
#
#         circle_marker_c255077ca9e8b873ca58e3538d0d3322.bindPopup(popup_8ecc4558894f64915f311b821ade830d)
#         ;
#
#
#
#
#             var circle_marker_18f8fbfb66c49b27548e3bf9139afc83 = L.circleMarker(
#                 [40.42756, -3.61577],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_66422fdbc76bdc969dc5909ed82fc69a);
#
#
#         var popup_71976c99abad97391975d68570e2780d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eafc218fa93d11d0dd4d09b4bd3375fa = $(`&lt;div id=&quot;html_eafc218fa93d11d0dd4d09b4bd3375fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_71976c99abad97391975d68570e2780d.setContent(html_eafc218fa93d11d0dd4d09b4bd3375fa);
#
#
#
#         circle_marker_18f8fbfb66c49b27548e3bf9139afc83.bindPopup(popup_71976c99abad97391975d68570e2780d)
#         ;
#
#
#
#
#             var circle_marker_76bdf5396e7b0772740b08dfbc9b15e9 = L.circleMarker(
#                 [40.42761, -3.6158],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_66422fdbc76bdc969dc5909ed82fc69a);
#
#
#         var popup_78e6cd831abe482cf196ed35252d66e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_82bd73f05616c00f96f6ee998001e1ab = $(`&lt;div id=&quot;html_82bd73f05616c00f96f6ee998001e1ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;29.4&lt;/div&gt;`)[0];
#                 popup_78e6cd831abe482cf196ed35252d66e0.setContent(html_82bd73f05616c00f96f6ee998001e1ab);
#
#
#
#         circle_marker_76bdf5396e7b0772740b08dfbc9b15e9.bindPopup(popup_78e6cd831abe482cf196ed35252d66e0)
#         ;
#
#
#
#
#             var circle_marker_1624e879a4da3eeb7bb7398ffaebf251 = L.circleMarker(
#                 [40.4267, -3.61631],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 1, &quot;fillRule&quo

# %% [markdown]
# **Insight 6: There are still many yellow and orange dots, which may indicate that there is still potential to further exploit the sporting event factor**
